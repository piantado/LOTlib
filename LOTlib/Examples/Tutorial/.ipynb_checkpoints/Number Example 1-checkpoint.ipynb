# %% [markdown]
# Learning Patterns in the Number Concept Domain
# ==============================================
#
# ### Background
# With a set of domain entities taken as input, a learner should be able to learn the rule that was used to generate these items. In this example, the *domain* is the set of natural numbers that we are considering. For this example, our domain will be the integers $n \in \mathbb{N}$ from 1 through 100.
#
# A *hypothesis* is a rule maps an input number $n \in [1,100]$ to an output number $f(n)$:
# $$ n \longrightarrow f(n) $$
# Since it also must be the case that $f(n) \in [1,100]$, each hypothesis maps to a subset $C$ of the domain.
#
#
# ### Example 1
# It is not the case, however, that a hypothesis is equivalent to its corresponding $C$. In our problem domain, rules are used to *generate* data. Children are capable of learning rules given only sparse positive data. For example, a child might be repeatedly told that 3, 5, 7, and 11 are odd numbers, but never explicitly learn that 9 is an odd number.
#
# In this case, the child's input data is $D = \{3,3,3,5,5,7,11,11,11\}$, while their hypothesis maps to the set $C = \{1,3,5,7,9,11,...,99\}$. The correct hypothesis for this data would correspond to the rule used to generate this data. The following rule maps $n \in [1,100]$ to $C$ and was used to generate $D$:
# $$ n \longrightarrow 2n - 1 $$
#
#
# ### Example 2
# On input $D = \{2, 4, 16, 64\}$, a learner should be able to recognize that these are all powers of 2. In other words, the hypothesis which was used to generate these numbers is:
# $$ n \longrightarrow 2^{n} $$
# This rule states that for some subset of the integers in the range $[1,100]$, there are mappings to other integers $f(n)=2^{n}$ in the same range. The full set of numbers correctly generated by this rule is: $C = \{2,4,8,16,32,64\}$.
#
# However, we can imagine other hypotheses which could generate this same data. For example, perhaps the rule is for powers of 2 except for the numbers 8 & 32:
# $$ A = \{n \mid n \in 2^{n}\} $$
# $$ C = A - \{8,32\} $$
# $D$ could have also been generated by an 'even numbers only' rule:
# $$ n \longrightarrow 2n $$
# or even by a rule with no constraints on the domain, where $C_{h} = [1,100]$:
# $$ n \longrightarrow n $$
#
# The first hypothesis has two advantages which make it superior to the other three.
#
# ###### Hypothesis complexity
# Equation 1 syntactically simpler than equation 2 (TODO: equation labels), which means it is more likely to be found by a learner searching through spaces of possible hypotheses.
#
# ###### Likelihood (of generating data)
# Second,  is more likely to generate $D$ than equations 3 or 4. E.g. for equation 4, $C_{h} = {1,2,...100}$, which means the probability of generating $n$

# %%
# %matplotlib inline
from math import log
import matplotlib.pyplot as plt

from LOTlib import lot_iter
from LOTlib.Grammar import Grammar
from LOTlib.Hypotheses.LOTHypothesis import *
from LOTlib.Evaluation.Eval import *
from LOTlib.Miscellaneous import logsumexp, exp

from LOTlib.Examples.Tutorial.number import NumberGameExpression


#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ 2 : Create grammar ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
# - Rules in our grammar map between sets of integers in our domain                     #
# - E.g. "3n+1" maps to { 1, 4, 7, 10, ... }                                            #
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
grammar = Grammar()
grammar.add_rule('START', '', ['EXPR'], 1)
# grammar.add_rule('EXPR', 'times_', ['EXPR', 'EXPR'], 1)
grammar.add_rule('EXPR', 'plus_', ['EXPR', 'EXPR'], 1)
# grammar.add_rule('EXPR', 'minus_', ['EXPR', 'EXPR'], 1)
grammar.add_rule('EXPR', 'pow_', ['EXPR', 'EXPR'], 1)

# Converted to digits so python can evaluate them
grammar.add_rule('EXPR', 'n', None, 10)
for i in range(1, 3):
    grammar.add_rule('EXPR', str(i), None, (10-i)/2)


#~~~~~~~~~~~~~~~~~~~~~~~~ 3 : Generate hypotheses for data ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
# Edit these parameters
num_iters = 5000
data = [3, 9, 17]
domain = 100
noise = 0.9
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
'''
from LOTlib.Inference.MetropolisHastings import MHSampler

hypotheses = set()
h0 = NumberGameExpression(grammar, domain=domain, noise=noise)
for h in MHSampler(h0, data, steps=num_iters):
    #print h   # with this you can see how hill climbing moves towards maxima
    hypotheses.add(h)
'''

hypotheses = set()
for _ in lot_iter(xrange(num_iters)):       # You can ctrl+C to exit this loop
    t = NumberGameExpression(grammar, domain=domain, noise=noise)
    t.compute_posterior(data)               # Get prior, likelihood, posterior
    hypotheses.add(t)

# exp(posterior_score) is proportional to posterior probability, so we estimate normalizing
# constant Z like so:
Z = logsumexp([h.posterior_score for h in hypotheses])


#~~~~~~~~~~~~ printing prior, likelihood, & normalized posterior score ~~~~~~~~~~~~~~~~~#
# for h in sorted(hypotheses, key=lambda x: x.posterior_score):
#     print h.prior, h.likelihood, exp(h.posterior_score - Z), h

print str(num_iters) + ' number of iterations'
print str(len(hypotheses)) + ' hypotheses in total'


#~~~~~~~~~ graph p(y in C | d) as a function of y in domain (see figs 3,4,9) ~~~~~~~~~~~#
# - NOTE: this does not calculate p(y in C | d);  change to describe what it does calc. #
predictive_dist = [0.]*domain

# Calculate chance of sampling for each item in domain
for q in range(domain):
    # Sum p(q|h) * p(h|D) for all hypotheses h
    for h in hypotheses:
        posterior = h.posterior_score - Z
        likelihood = h.compute_likelihood([q+1])
        predictive_dist[q] += exp(posterior + likelihood)
        # if (likelihood / posterior) > 10:
        #     print '\nh: '+str(h)+'\nq: '+str(q)+'\npost: '+str(posterior)+'\nlike: '+str(
        #         likelihood)+'\n~~~~~~~~~~'

fig, ax = plt.subplots()
rects = plt.bar(range(1,domain+1), predictive_dist)

plt.xlabel('Domain (from 1 to '+str(domain)+')')
plt.ylabel('Probability of sampling this value')
plt.title('This graph needs a title!')

plt.show()
# Out:
# Generating  50000  hypotheses...
#
# ...
# 10 :	Hypothesis:	pow_(plus_(1, 2), n)
# 	Posterior:	0.00288
# ...
# 9 :	Hypothesis:	pow_(plus_(2, 1), n)
# 	Posterior:	0.00288
# ...
# 8 :	Hypothesis:	pow_(n, 1)
# 	Posterior:	0.00564
# ...
# 7 :	Hypothesis:	plus_(1, n)
# 	Posterior:	0.00579
# ...
# 6 :	Hypothesis:	plus_(n, 1)
# 	Posterior:	0.00579
# ...
# 5 :	Hypothesis:	plus_(2, n)
# 	Posterior:	0.00596
# ...
# 4 :	Hypothesis:	plus_(n, 2)
# 	Posterior:	0.00596
# ...
# 3 :	Hypothesis:	plus_(1, pow_(2, n))
# 	Posterior:	0.19417
# ...
# 2 :	Hypothesis:	plus_(pow_(2, n), 1)
# 	Posterior:	0.19417
# ...
# 1 :	Hypothesis:	n
# 	Posterior:	0.56397
# ...
#
#
# 50000 total hypotheses generated
# 435 unique hypotheses
# 5000 number of iterations
# 112 hypotheses in total
